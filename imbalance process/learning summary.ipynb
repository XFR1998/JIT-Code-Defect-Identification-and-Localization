# %%
import sklearn
from sklearn.datasets import make_classification
import numpy as np
import pandas as pd

# %%
# 生成不平衡的9：1数据集
data_x, data_y=make_classification(n_classes=2,class_sep=2,weights=[0.9,0.1],n_informative=3,n_redundant=1,flip_y=0,n_features=20,n_clusters_per_class=1,
                        n_samples=1000,random_state=10)
print(pd.Series(data_y).value_counts())

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data_x, data_y, test_size=0.2, random_state=42)
print(pd.Series(y_train).value_counts())
# Out:
# 0    900
# 1    100
# dtype: int64
# 0    719
# 1     81
# dtype: int64

# %%
from sklearn.svm import SVC
model = SVC(kernel='rbf', verbose=True)
model.fit(x_train, y_train)
from sklearn.metrics import accuracy_score, f1_score,recall_score,precision_score
y_pred = model.predict(x_test)
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)

print('\nacc: {}\nf1: {}\nrecall: {}\nprecision: {}'.format(acc, f1, recall, precision))
# Out:
# [LibSVM]
# acc: 1.0
# f1: 1.0
# recall: 1.0
# precision: 1.0

# %%
df

# %%
df = pd.read_excel('./pqlcc_corr_data.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 393 entries, 0 to 392
# Data columns (total 49 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   creator_job                               393 non-null    int64
#  1   is_member                                 393 non-null    int64
#  2   scale                                     393 non-null    int64
#  3   name                                      393 non-null    int64
#  4   demand                                    393 non-null    int64
#  5   is_whole_fillin                           393 non-null    int64
#  6   corpdep_grouptype                         393 non-null    int64
#  7   industry_info                             393 non-null    int64
#  8   space_usage_rate                          393 non-null    int64
#  9   company_doc_number                        393 non-null    int64
# ...

# %%
df = pd.read_excel('./pqlcc_corr_data.xlsx')
# df['active_user_last30'] = df['active_user_last30'].apply(lambda x: int(x))
df = df.iloc[:,1:30]
df.dropna()
df.info()
df.head(5)
# df.corr()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 393 entries, 0 to 392
# Data columns (total 29 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   is_member                                 393 non-null    int64
#  1   scale                                     393 non-null    int64
#  2   name                                      393 non-null    int64
#  3   demand                                    393 non-null    int64
#  4   is_whole_fillin                           393 non-null    int64
#  5   corpdep_grouptype                         393 non-null    int64
#  6   industry_info                             393 non-null    int64
#  7   space_usage_rate                          393 non-null    int64
#  8   company_doc_number                        393 non-null    int64
#  9   subrecylebin_clean                        393 non-null    int64
# ...

# %%
import seaborn as sb
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(20, 20))
sb.heatmap(df.corr(), annot=True)
f.savefig('./corr.jpg')

# %%
# sum(df['active_user_last30'].isnull())

# %%
for i in df['active_user_last30']:
    if i==np.nan:
        print(666)

# %%
df.corr()
